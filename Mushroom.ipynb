# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mushroom=pd.read_csv(r'C:\Users\delkl\Desktop\mushrooms.csv')

# %%
mushroom
# Out:
#                class        cap-shape cap-surface cap-color bruises odor  \
# 0                  p                x           s         n       t    p
# 1                  e                x           s         y       t    a
# 2                  e                b           s         w       t    l
# 3                  p                x           y         w       t    p
# 4                  e                x           s         g       f    n
# ...              ...              ...         ...       ...     ...  ...
# 8120               e                x           s         n       f    n
# 8121               e                f           s         n       f    n
# 8122               p                k           y         n       f    y
# 8123               e                x           s         n       f    n
# 8124  {"mode":"full"  isActive:false}         NaN       NaN     NaN  NaN
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# ...

# %%
mushroom.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %%
mushroom.tail(10)
# Out:
#                class        cap-shape cap-surface cap-color bruises odor  \
# 8115               e                x           s         n       f    n
# 8116               p                k           y         n       f    s
# 8117               p                k           s         e       f    y
# 8118               p                k           y         n       f    f
# 8119               e                k           s         n       f    n
# 8120               e                x           s         n       f    n
# 8121               e                f           s         n       f    n
# 8122               p                k           y         n       f    y
# 8123               e                x           s         n       f    n
# 8124  {"mode":"full"  isActive:false}         NaN       NaN     NaN  NaN
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 8115               a            c         b          y  ...
# ...

# %%
mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8125 entries, 0 to 8124
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8125 non-null   object
#  1   cap-shape                 8125 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
mushroom.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 1
# cap-color                   1
# bruises                     1
# odor                        1
# gill-attachment             1
# gill-spacing                1
# gill-size                   1
# gill-color                  1
# stalk-shape                 1
# stalk-root                  1
# stalk-surface-above-ring    1
# stalk-surface-below-ring    1
# stalk-color-above-ring      1
# stalk-color-below-ring      1
# veil-type                   1
# veil-color                  1
# ring-number                 1
# ring-type                   1
# spore-print-color           1
# population                  1
# habitat                     1
# dtype: int64

# %%
mushroom.dropna(inplace=True)

# %%
mushroom.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
mushroom.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
sb.heatmap(mushroom.isnull(), yticklabels=False,cbar=False,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
mushroom.duplicated().sum()
# Out:
# 0
